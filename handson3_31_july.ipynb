# %% [markdown]
# CHINESE SEGMENTATION USING JIEBA

# %%
# !pip install jieba

# %%
import jieba
seg = jieba.cut("把句子中所有的可以成词的词语都扫描出来", cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/1b/09258dts29b424qrrntd5qn00000gn/T/jieba.cache
# Loading model cost 1.082 seconds.
# Prefix dict has been built successfully.
# 把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来

# %% [markdown]
# TEXT PROCESSING PIPELINE

# %%
import nltk
texts = ''' Natural language processing (NLP) is a subfield of linguistics, computer science, information engineering,
and artificial intelligence concerned with the interactions between computers and human (natural) languages, in 
particular how to program computers to process and analyze large amounts of natural language data.Challenges in 
natural language processing frequently involve speech recognition, natural language understanding, and natural language 
generation.The history of natural language processing (NLP) generally started in the 1950s, although work can be found
from earlier periods. In 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which 
proposed what is now called the Turing test as a criterion of intelligence'''

for text in texts :
    sentences =  nltk.sent_tokenize(texts)
    print(sentences)
# Out:
# [' Natural language processing (NLP) is a subfield of linguistics, computer science, information engineering,\nand artificial intelligence concerned with the interactions between computers and human (natural) languages, in \nparticular how to program computers to process and analyze large amounts of natural language data.Challenges in \nnatural language processing frequently involve speech recognition, natural language understanding, and natural language \ngeneration.The history of natural language processing (NLP) generally started in the 1950s, although work can be found\nfrom earlier periods.', 'In 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which \nproposed what is now called the Turing test as a criterion of intelligence']
# ...

# %%
for text in texts :
    sentences =  nltk.sent_tokenize(texts)
    for sentence in sentences: 
        words =  nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(words)
        print(tagged)
# Out:
# [('Natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('(', '('), ('NLP', 'NNP'), (')', ')'), ('is', 'VBZ'), ('a', 'DT'), ('subfield', 'NN'), ('of', 'IN'), ('linguistics', 'NNS'), (',', ','), ('computer', 'NN'), ('science', 'NN'), (',', ','), ('information', 'NN'), ('engineering', 'NN'), (',', ','), ('and', 'CC'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('concerned', 'VBN'), ('with', 'IN'), ('the', 'DT'), ('interactions', 'NNS'), ('between', 'IN'), ('computers', 'NNS'), ('and', 'CC'), ('human', 'JJ'), ('(', '('), ('natural', 'JJ'), (')', ')'), ('languages', 'NNS'), (',', ','), ('in', 'IN'), ('particular', 'JJ'), ('how', 'WRB'), ('to', 'TO'), ('program', 'NN'), ('computers', 'NNS'), ('to', 'TO'), ('process', 'VB'), ('and', 'CC'), ('analyze', 'VB'), ('large', 'JJ'), ('amounts', 'NNS'), ('of', 'IN'), ('natural', 'JJ'), ('language', 'NN'), ('data.Challenges', 'NNS'), ('in', 'IN'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('frequently', 'RB'), ('involve',
# ...

# %% [markdown]
# TWEET TOKENIZER

# %%
from nltk.tokenize import TweetTokenizer 
text = 'The party was sooo fun :D #superfun'
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'party', 'was', 'sooo', 'fun', ':D', '#superfun']

# %% [markdown]
# SCANNING DATA FROM WEB

# %%
from urllib import request 
url = " http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
# Out:
# str

# %%
print(raw[:50])
# Out:
# ﻿The Project Gutenberg EBook of Crime and Punishme

# %%
from nltk.tokenize import word_tokenize
tokens=word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
print(tokens[:10])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'Crime', 'and', 'Punishment', ',', 'by']

# %%
text = ' '.join(tokens)
type(text)
# Out:
# str

# %%
vocab = sorted(set(tokens))
type(vocab)
# Out:
# list
